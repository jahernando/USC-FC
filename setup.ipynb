# %% [markdown]
# # Computational Physics
#
#
# ## More about Python : Functions and Classes
#
#
# #### *J.A. Hernando Morata*, in collaboration wtih *G. Martínez-Lema*, *M. Kekic*.
# ####  USC, October 2020
#
#
#
# ## Material

# %%
import time
print('Last revision ', time.asctime())
# Out:
# Last revision  Thu Oct 22 11:56:55 2020

# %% [markdown]
# ### What you must know
#
#
# * The basic of Python code. [Python](https://www.python.org)
#
#
# * Editing an executing a Python module.
#
#     * Some editors: [atom](https://atom.io), [spyder](https://www.spyder-ide.org) or [emacs](https://www.gnu.org/software/emacs/).
#
#
# * Work in Anacoda environment. [Anaconda](https://www.anaconda.com)
#
#
# * Know about [Jupyter Notebooks](https:jupyter.org)
#
#
# * Preferable to know [numpy](http://www.numpy.org ), [pandas](http://pandas.pydata.org) and [matplotlib](http://matplotlib.org) modules to do data analysis.
#
#
# * Prefereable some [Unix](https://es.wikipedia.org/wiki/Unix) knowledge.

# %% [markdown]
# ### Materials of this course
#
# * Materials are Jupyter Notebooks (NB).
#
#
# * The NBs are at this [GitHub](https://github.com) repository: [jahernando/USC-FC](https://github.com/jahernando/USC-FC)
#
#
#    * This is the [index](https://github.com/jahernando/USC-FC/blob/main/index.ipynb) of the course.

# %% [markdown]
# ### You can get a local copy of the repository
#
# Either one of these:
#
#   * under *Code* tab in the [jahernando/USC-FC](https://github.com/jahernando/USC-FC) repository page, *download zip* it. And unzip it in your local area.
#
#   * In a Unix console, clone the repository your local directory via the command:
#
#           git clone https://github.com/jahernando/USC-FC.git
#
#
#    * If you have a GitHub account, *fork* the repository to your own GitHub area and then clone it to your local directory.

# %% [markdown]
# ### You can open locally the notebooks:
#
#    * via Anaconda, in Windows, look for the Jypyter icon: ![NB](https://jupyter.org/assets/main-logo.svg)
#
#    * in the Unix console, in the directory where you cloned the repository, via the command:
#
#           jupyter notebook &

# %% [markdown]
# ### You can remotely execute the NBs
#
#    * click in this Binder icon: [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jahernando/USC-FC/main) or at the same icon at end of the [jahernando/USC-FP](https://github.com/jahernando/USC-FC) repository main page.
#
#
#    * if you have a Google account, open the NBs with [Google Colab](https://colab.research.google.com) at the GitHub [jahernado/USC-FP](https://github.com/jahernando/USC-FC) repository.
